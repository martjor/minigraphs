# %%
import networkx as nx 
from minigraphs import inspection 

graph = nx.erdos_renyi_graph(100, 0.05)
pos = nx.forceatlas2_layout(graph)

inspection.draw_subgraph(graph, [0,2,5, 3, 7], pos)
# Out:
# <Axes: >
