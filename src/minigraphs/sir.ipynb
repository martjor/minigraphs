# %%
import networkx as nx

graph = nx.erdos_renyi_graph(200, 0.05)

# %%
from minigraphs.simulation import SIRModel
from mesa.batchrunner import batch_run
from functools import partial 
import pandas as pd

Model = partial(SIRModel, network=graph)

results = batch_run(
    Model, 
    {'beta': 0.1, 'gamma': 0.1, 'n_infected':1},
    number_processes=None, 
    iterations=10, 
    data_collection_period=1,
    max_steps=100
)

df = pd.DataFrame(results)
df
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#       RunId  iteration  Step  beta  gamma  n_infected    S   I  R  \
# 0         4          4     0   0.1    0.1           1  199   1  0
# 1         4          4     1   0.1    0.1           1  198   1  0
# 2         4          4     2   0.1    0.1           1  196   3  0
# 3         4          4     3   0.1    0.1           1  191   8  0
# 4         4          4     4   0.1    0.1           1  183  15  1
# ...     ...        ...   ...   ...    ...         ...  ...  .. ..
# 1005      1          1    96   0.1    0.1           1  199   0  0
# 1006      1          1    97   0.1    0.1           1  199   0  0
# 1007      1          1    98   0.1    0.1           1  199   0  0
# 1008      1          1    99   0.1    0.1           1  199   0  0
# 1009      1          1   100   0.1    0.1           1  199   0  0
#
#       n_new_infections
# 0                    0
# 1                  199
# 2                  198
# 3                  196
# 4                  191
# ...                ...
# 1005               199
# 1006               199
# 1007               199
# 1008               199
# 1009               199
#
# [1010 rows x 10 columns]
